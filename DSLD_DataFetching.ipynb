# %% [markdown]
# # Import libraries

# %%
import pymongo
import json
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# # Create/Connect to a database and a collection

# %%
# Connection to Mongo DB
try:
    client = pymongo.MongoClient()
    print ("Connected to MongoDB successfully!!!")
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e)

db = client.DSlabel_db
collection = db.DSlabel_collection_final
# Out:
# Connected to MongoDB successfully!!!

# %%
print ("Databases:", client.database_names())
print ("Collections:", db.collection_names())
print ('Number of documents:', collection.count())
# Out:
# Databases: ['DSlabel_db', 'admin', 'local']
# Collections: ['DSlabel_collection_final']
# Number of documents: 65499

# %% [markdown]
# # Insert documents into collection

# %%
collection.drop()

# %%
all_products = pd.read_csv('data/DSLD_AllProducts.csv')
DSLD_API = "http://dsld.nlm.nih.gov/dsld/api/label/"

for DSLD_ID in all_products['DSLD ID']:
    try:
        current_url = '{0}{1}'.format(DSLD_API, DSLD_ID)
        print('Fetching data from {}'.format(current_url))
        
        response = requests.get(current_url)
        data = response.json()
        label_id = collection.insert_one(data).inserted_id
        
    except requests.exceptions.RequestException as e:  
        print (e)

# %%
print ("Databases:", client.database_names())
print ("Collections:", db.collection_names())
print ('Number of documents:', collection.count())

# %% [markdown]
# # Get the keys of the collection

# %%
cursor = collection.aggregate([
          {"$project":{"arrayofkeyvalue":{"$objectToArray":"$$ROOT"}}},
          {"$unwind":"$arrayofkeyvalue"},
          {"$group":{"_id":'null',"allkeys":{"$addToSet":"$arrayofkeyvalue.k"}}}
        ])
pprint(list(cursor))
# Out:
# [{'_id': 'null',
#   'allkeys': ['Tracking_History',
#               'contacts',
#               'LanguaL_Intended_Target_Groups',
#               'Brand',
#               'statements',
#               'ingredients',
#               'LanguaL_Product_Type',
#               'Serving_Size',
#               'LanguaL_Supplement_Form',
#               'DSLD_ID',
#               'count',
#               'Product_Name',
#               '_id',
#               'Outer_Packaging',
#               'Suggested_Use',
#               'LanguaL_Dietary_Claim_or_Use',
#               'NHANES_ID',
#               'success',
#               'Date_Entered_into_DSLD',
#               'Database',
#               'Net_Contents_Quantity',
#               'Product_Trademark_Copyright_Symbol',
#               'Statement_of_Identity',
#               'SKU',
#               'DB_Source']}]

# %%
pprint(collection.find_one())
# Out:
# {'Brand': '+nuun',
#  'DB_Source': 'Version 7.0.1 - October 2017, Rev 2503 (46eaaddd8e99)',
#  'DSLD_ID': '40479',
#  'Database': 'adsld',
#  'Date_Entered_into_DSLD': 'December 29, 2014',
#  'LanguaL_Dietary_Claim_or_Use': 'OTHER INGREDIENT- OR CONSTITUENT-RELATED '
#                                  'CLAIM OR USE [P0115]',
#  'LanguaL_Intended_Target_Groups': 'HUMAN CONSUMER, FOUR YEARS AND ABOVE '
#                                    '[P0250]',
#  'LanguaL_Product_Type': 'MULTI-VITAMIN AND MULTI-MINERAL SUPPLEMENT [A1315]',
#  'LanguaL_Supplement_Form': 'TABLET [E0155]',
#  'NHANES_ID': '',
#  'Net_Contents_Quantity': '15.0 Tab(s)Alternate 58.0 Gram(s)',
#  'Outer_Packaging': 'Not Present',
#  'Product_Name': '+nuun All Day Blueberry Pomegranate',
#  'Product_Trademark_Copyright_Symbol': '',
#  'SKU': 'Not Present',
#  'Serving_Size': ' 1.0 Tablet(s)',
#  'Statement_of_Identity': '',
#  'Suggested_Use': '',
#  'Tracking_History': 'Date - Entered into DSLD: December 29, 2014',
#  '_id': ObjectId('5a98485c36745709af7d057a'),
#  'contacts': [{'Address': None,
#                'City': None,
#                'DSLD_ID': '40479',
#                'IS_DISTRIBUTOR': 'No',
#                'IS_MANUFACTURER': 'No',
#                'IS_OTHER': 'Yes',
#                'IS_PACKAGER': 'No',
#                'IS_RESELLER': 'No',
#                'Name': None,
#                'State': None,
#                'Type': 'visit us at',
#                'ZIP': None},
#               {'Address': '800 Maynard Ave S, STE 102',
#                'City': 'SEATTLE',
#                'DSLD_ID': '40479',
#                'IS_DISTRIBUTOR': 'Yes',
#                'IS_MANUFACTURER': 'No',
#                'IS_OTHER': 'No',
#                'IS_PACKAGER': 'No',
#                'IS_RESELLER': 'No',
#                'Name': 'NUUN & CO.',
#                'State': 'WA',
#                'Type': 'MADE IN USA FOR',
#                'ZIP': '98134'},
#               {'Address': None,
#                'City': None,
#                'DSLD_ID': '40479',
#                'IS_DISTRIBUTOR': 'No',
#                'IS_MANUFACTURER': 'No',
#                'IS_OTHER': 'Yes',
#                'IS_PACKAGER': 'No',
#                'IS_RESELLER': 'No',
#                'Name': None,
#                'State': None,
#                'Type': 'Toll Free',
#                'ZIP': None}],
#  'count': 1,
#  'ingredients': [{'Amount_Per_Serving': '7.0',
#                   'Amount_Serving_Unit': '{Calories}',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491880',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'header',
#                   'Dietary_Ingredient_Synonym_Source': 'Calories   ',
#                   'Ingredient_Group_GRP_ID': '',
#                   'Ingredient_ID': '7388',
#                   'Pct_Daily_Value_per_Serving': '',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '0.0',
#                   'Amount_Serving_Unit': 'Gram(s)',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491881',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'other',
#                   'Dietary_Ingredient_Synonym_Source': 'Calories from Fat   ',
#                   'Ingredient_Group_GRP_ID': '128',
#                   'Ingredient_ID': '24846',
#                   'Pct_Daily_Value_per_Serving': '',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '0.0',
#                   'Amount_Serving_Unit': 'Gram(s)',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491891',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'fat',
#                   'Dietary_Ingredient_Synonym_Source': 'Total Fat   ',
#                   'Ingredient_Group_GRP_ID': '87',
#                   'Ingredient_ID': '12205',
#                   'Pct_Daily_Value_per_Serving': '',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '1.0',
#                   'Amount_Serving_Unit': 'Gram(s)',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491872',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'carbohydrate',
#                   'Dietary_Ingredient_Synonym_Source': 'Total Carb   ',
#                   'Ingredient_Group_GRP_ID': '28',
#                   'Ingredient_ID': '18577',
#                   'Pct_Daily_Value_per_Serving': '1.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '0.0',
#                   'Amount_Serving_Unit': 'Gram(s)',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491873',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'carbohydrate',
#                   'Dietary_Ingredient_Synonym_Source': 'Sugars   ',
#                   'Ingredient_Group_GRP_ID': '2475',
#                   'Ingredient_ID': '17792',
#                   'Pct_Daily_Value_per_Serving': '',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '0.0',
#                   'Amount_Serving_Unit': 'Gram(s)',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491882',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'protein',
#                   'Dietary_Ingredient_Synonym_Source': 'Protein   ',
#                   'Ingredient_Group_GRP_ID': '107',
#                   'Ingredient_ID': '18344',
#                   'Pct_Daily_Value_per_Serving': '',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '750.0',
#                   'Amount_Serving_Unit': 'IU',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491871',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin A   (as '
#                                                        'Retinyl Acetate)  ',
#                   'Ingredient_Group_GRP_ID': '201',
#                   'Ingredient_ID': '17854',
#                   'Pct_Daily_Value_per_Serving': '15.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '60.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491883',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin C  (Ascorbic '
#                                                        'Acid)   ',
#                   'Ingredient_Group_GRP_ID': '10',
#                   'Ingredient_ID': '17981',
#                   'Pct_Daily_Value_per_Serving': '100.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '200.0',
#                   'Amount_Serving_Unit': 'IU',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491892',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin D   (as '
#                                                        'Cholecalciferol)  ',
#                   'Ingredient_Group_GRP_ID': '207',
#                   'Ingredient_ID': '18024',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '15.0',
#                   'Amount_Serving_Unit': 'IU',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491893',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin E   (as '
#                                                        'DL-Tocopheryl '
#                                                        'Acetate)  ',
#                   'Ingredient_Group_GRP_ID': '50',
#                   'Ingredient_ID': '90475',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '750.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491874',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Thiamin   (as Thiamine '
#                                                        'Mononitrate)  ',
#                   'Ingredient_Group_GRP_ID': '126',
#                   'Ingredient_ID': '87801',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '850.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491875',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': '',
#                   'Dietary_Ingredient_Synonym_Source': 'Riboflavin   (as '
#                                                        'Riboflavin)  ',
#                   'Ingredient_Group_GRP_ID': '',
#                   'Ingredient_ID': '65380',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '10.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491884',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Niacin   (as '
#                                                        'Niacinamide)  ',
#                   'Ingredient_Group_GRP_ID': '2544',
#                   'Ingredient_ID': '17268',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '1.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491885',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin B6   (as '
#                                                        'Pyridoxine HCl)  ',
#                   'Ingredient_Group_GRP_ID': '110',
#                   'Ingredient_ID': '20074',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '3.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491877',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Vitamin B12   (as '
#                                                        'Cyanocobalamin)  ',
#                   'Ingredient_Group_GRP_ID': '202',
#                   'Ingredient_ID': '17943',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '5.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491878',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'vitamin',
#                   'Dietary_Ingredient_Synonym_Source': 'Pantothenic Acid   (as '
#                                                        'D-Calcium '
#                                                        'Pantothenate)  ',
#                   'Ingredient_Group_GRP_ID': '98',
#                   'Ingredient_ID': '17451',
#                   'Pct_Daily_Value_per_Serving': '50.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '20.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491887',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Magnesium   (as '
#                                                        'Magnesium Oxide)  ',
#                   'Ingredient_Group_GRP_ID': '82',
#                   'Ingredient_ID': '4999',
#                   'Pct_Daily_Value_per_Serving': '5.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '750.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491888',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Zinc   (as Zinc '
#                                                        'Sulfate)  ',
#                   'Ingredient_Group_GRP_ID': '137',
#                   'Ingredient_ID': '17657',
#                   'Pct_Daily_Value_per_Serving': '5.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '3.5',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491886',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Selenium   (as '
#                                                        'Selenium Chelate)  ',
#                   'Ingredient_Group_GRP_ID': '147',
#                   'Ingredient_ID': '43529',
#                   'Pct_Daily_Value_per_Serving': '5.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '100.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491876',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Manganese   (as '
#                                                        'Manganese Gluconate)  ',
#                   'Ingredient_Group_GRP_ID': '252',
#                   'Ingredient_ID': '16938',
#                   'Pct_Daily_Value_per_Serving': '5.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '6.0',
#                   'Amount_Serving_Unit': 'mcg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491890',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Chromium   (as '
#                                                        'Chromium '
#                                                        'Polynicotinate)  ',
#                   'Ingredient_Group_GRP_ID': '41',
#                   'Ingredient_ID': '73024',
#                   'Pct_Daily_Value_per_Serving': '5.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '60.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491889',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': '',
#                   'Dietary_Ingredient_Synonym_Source': 'Sodium   (as Sodium '
#                                                        'Bicarbonate)  ',
#                   'Ingredient_Group_GRP_ID': '',
#                   'Ingredient_ID': '38964',
#                   'Pct_Daily_Value_per_Serving': '3.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''},
#                  {'Amount_Per_Serving': '200.0',
#                   'Amount_Serving_Unit': 'mg',
#                   'Ancestry__Number_of_Parents_Row_IDs': '0,491879',
#                   'Blended_Ingredient_Types': '',
#                   "Blends'_Ancestry": None,
#                   'DSLD_ID': '40479',
#                   'DSLD_Ingredient_Categories': 'mineral',
#                   'Dietary_Ingredient_Synonym_Source': 'Potassium   (as '
#                                                        'Potassium Bicarbonate, '
#                                                        'Potassium Carbonate)  ',
#                   'Ingredient_Group_GRP_ID': '106',
#                   'Ingredient_ID': '4790',
#                   'Pct_Daily_Value_per_Serving': '6.0 %',
#                   'Serving_Size': '1.0 Tablet(s)',
#                   'Suggested_Recommended_Usage_Directions:': ''}],
#  'statements': [{'DSLD_ID': '40479',
#                  'Statement': 'UNDER 8 CALORIES',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': '{Recycle} 5 PP',
#                  'Statement_Type': 'Seals/Symbols'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'vitamin enhanced drink tabs for all day '
#                               'hydration',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'ALL NATURAL, ZERO SUGAR',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': '+ zero sugar',
#                  'Statement_Type': 'Formulation'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'REUSE YOUR BOTTLE',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'ALL NATURAL, ZERO SUGAR\n\n',
#                  'Statement_Type': 'Formulation'},
#                 {'DSLD_ID': '40479',
#                  'Statement': '15 tabs inside',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'DRINK YOUR VITAMINS\n\n+ A B C D E',
#                  'Statement_Type': 'Other'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'store below 25c/80f',
#                  'Statement_Type': 'Product Specific Information'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'Use only if cap seal is unbroken',
#                  'Statement_Type': 'Precautions'},
#                 {'DSLD_ID': '40479',
#                  'Statement': 'Not Present',
#                  'Statement_Type': None}],
#  'success': True}

# %% [markdown]
# # create a subset of the collection

# %%
cursor = collection.find({}, {'DSLD_ID': 1,
                              'Brand': 1, 
                              'Product_Name': 1,
                              'LanguaL_Intended_Target_Groups': 1,
                              'LanguaL_Dietary_Claim_or_Use': 1,
                              'statements': 1,
                              'ingredients': 1,
                              'LanguaL_Product_Type': 1,
                              'LanguaL_Supplement_Form': 1,
                              'Serving_Size': 1,
                              'success': 1,
                              '_id':0
                             })

# %%
print('{} documents in collection'.format(cursor.count()))
# Out:
# 65499 documents in collection

# %% [markdown]
# # Convert to pandas Dataframe and explore

# %%
# Expand the cursor and construct the DataFrame
DS_label_df = pd.DataFrame(list(cursor))

# %%
DS_label_df.shape
# Out:
# (65499, 11)

# %%
DS_label_df.columns
# Out:
# Index(['Brand', 'DSLD_ID', 'LanguaL_Dietary_Claim_or_Use',
#        'LanguaL_Intended_Target_Groups', 'LanguaL_Product_Type',
#        'LanguaL_Supplement_Form', 'Product_Name', 'Serving_Size',
#        'ingredients', 'statements', 'success'],
#       dtype='object')

# %%
DS_label_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65499 entries, 0 to 65498
# Data columns (total 11 columns):
# Brand                             65499 non-null object
# DSLD_ID                           65499 non-null object
# LanguaL_Dietary_Claim_or_Use      65499 non-null object
# LanguaL_Intended_Target_Groups    65499 non-null object
# LanguaL_Product_Type              65499 non-null object
# LanguaL_Supplement_Form           65499 non-null object
# Product_Name                      65499 non-null object
# Serving_Size                      65499 non-null object
# ingredients                       65499 non-null object
# statements                        65499 non-null object
# success                           65499 non-null bool
# dtypes: bool(1), object(10)
# memory usage: 5.1+ MB

# %%
DS_label_df.head()
# Out:
#    Brand DSLD_ID                       LanguaL_Dietary_Claim_or_Use  \
# 0  +nuun   40479  OTHER INGREDIENT- OR CONSTITUENT-RELATED CLAIM...
# 1  +nuun   40480  OTHER INGREDIENT- OR CONSTITUENT-RELATED CLAIM...
# 2  +nuun   40464  OTHER INGREDIENT- OR CONSTITUENT-RELATED CLAIM...
# 3  +nuun   40438  OTHER INGREDIENT- OR CONSTITUENT-RELATED CLAIM...
# 4  +nuun   40456  OTHER INGREDIENT- OR CONSTITUENT-RELATED CLAIM...
#
#                  LanguaL_Intended_Target_Groups  \
# 0  HUMAN CONSUMER, FOUR YEARS AND ABOVE [P0250]
# 1  HUMAN CONSUMER, FOUR YEARS AND ABOVE [P0250]
# 2  HUMAN CONSUMER, FOUR YEARS AND ABOVE [P0250]
# 3  HUMAN CONSUMER, FOUR YEARS AND ABOVE [P0250]
# 4  HUMAN CONSUMER, FOUR YEARS AND ABOVE [P0250]
#
#                                 LanguaL_Product_Type LanguaL_Supplement_Form  \
# 0  MULTI-VITAMIN AND MULTI-MINERAL SUPPLEMENT [A1...          TABLET [E0155]
# 1  MULTI-VITAMIN AND MULTI-MINERAL SUPPLEMENT [A1...          TABLET [E0155]
# 2  MULTI-VITAMIN AND MULTI-MINERAL SUPPLEMENT [A1...          TABLET [E0155]
# 3  BOTANICAL SUPPLEMENT WITH VITAMIN/MINERAL [A1317]          TABLET [E0155]
# 4  BOTANICAL SUPPLEMENT WITH VITAMIN/MINERAL [A1317]          TABLET [E0155]
#
#                                    Product_Name  \
# 0           +nuun All Day Blueberry Pomegranate
# 1                 +nuun All Day Grape Raspberry
# 2                  +nuun All Day Tangerine Lime
# 3  +nuun Natural Hydration Goji Berry Green Tea
# 4      +nuun Natural Hydration Tangerine Ginger
#
#                        Serving_Size  \
# 0                     1.0 Tablet(s)
# 1                     1.0 Tablet(s)
# 2                     1.0 Tablet(s)
# 3   16.0 fl. Oz.Alternate  475.0 mL
# 4        1.0 Effervescent Tablet(s)
#
#                                          ingredients  \
# 0  [{'Ingredient_ID': '7388', 'DSLD_Ingredient_Ca...
# 1  [{'Ingredient_ID': '7388', 'DSLD_Ingredient_Ca...
# 2  [{'Ingredient_ID': '7388', 'DSLD_Ingredient_Ca...
# 3  [{'Ingredient_ID': '7388', 'DSLD_Ingredient_Ca...
# 4  [{'Ingredient_ID': '7388', 'DSLD_Ingredient_Ca...
#
#                                           statements  success
# 0  [{'Statement': 'UNDER 8 CALORIES', 'Statement_...     True
# 1  [{'Statement': 'ALL NATURAL, ZERO SUGAR', 'Sta...     True
# 2  [{'Statement': 'DRINK YOUR VITAMINS
#
# + A B C D...     True
# 3  [{'Statement': 'Use only if cap seal is unbrok...     True
# 4  [{'Statement': 'by +nuun', 'Statement_Type': '...     True

# %% [markdown]
# # Pickle the dataframe

# %%
# write dataframe
DS_label_df.to_csv('data/DietarySupplementLabelDatabase.csv', index=False)
DS_label_df.to_pickle('data/DietarySupplementLabelDatabase.pkl')

# %%
# read dataframe
DS_label_df = pd.read_pickle('data/DietarySupplementLabelDatabase.pkl')
